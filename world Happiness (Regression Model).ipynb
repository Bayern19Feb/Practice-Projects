# %%
# Importing important libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>

# %%
# to display all the columns

pd.set_option('display.max_columns', None)

# %%
# Reading dataframe
df = pd.read_csv("2015.csv")

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
# Its a regression problem
# Predicting the Happiness score
# Happiness score is a continuous variable

# %%
# top 5 countries
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
# Bottom 5 countries
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
# Lets use Describe to find more info
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
# Happiness score ranges approx from 3 - 8
# Max (GDP per Capita) 1.69

# %%
# lets check the country with the highest happiness score
df.iloc[0,:]
# Out:
# Country                             Switzerland
# Region                           Western Europe
# Happiness Rank                                1
# Happiness Score                           7.587
# Standard Error                          0.03411
# Economy (GDP per Capita)                1.39651
# Family                                  1.34951
# Health (Life Expectancy)                0.94143
# Freedom                                 0.66557
# Trust (Government Corruption)           0.41978
# Generosity                              0.29678
# Dystopia Residual                       2.51738
# Name: 0, dtype: object

# %%
# lets check the country with the lowest happiness score 
df.iloc[157,:]
# Out:
# Country                                        Togo
# Region                           Sub-Saharan Africa
# Happiness Rank                                  158
# Happiness Score                               2.839
# Standard Error                              0.06727
# Economy (GDP per Capita)                    0.20868
# Family                                      0.13995
# Health (Life Expectancy)                    0.28443
# Freedom                                     0.36453
# Trust (Government Corruption)               0.10731
# Generosity                                  0.16681
# Dystopia Residual                           1.56726
# Name: 157, dtype: object

# %%
# lets check for missing values
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
# No missing values

# %%
df.hist(bins=35,figsize=(20,20),color="green")
# Out:
# array([[<AxesSubplot:title={'center':'Happiness Rank'}>,
#         <AxesSubplot:title={'center':'Happiness Score'}>,
#         <AxesSubplot:title={'center':'Standard Error'}>],
#        [<AxesSubplot:title={'center':'Economy (GDP per Capita)'}>,
#         <AxesSubplot:title={'center':'Family'}>,
#         <AxesSubplot:title={'center':'Health (Life Expectancy)'}>],
#        [<AxesSubplot:title={'center':'Freedom'}>,
#         <AxesSubplot:title={'center':'Trust (Government Corruption)'}>,
#         <AxesSubplot:title={'center':'Generosity'}>],
#        [<AxesSubplot:title={'center':'Dystopia Residual'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
# Most of the GDP lies between 0.75 to 1.5
# Generosity lies between 0.1,0.4

# %%
# Top 5 happiest countries
df.groupby('Country')['Happiness Score'].max().sort_values(ascending=False).head(5).plot(kind='bar', figsize=(8,5),color='pink')
plt.title('Top 5 happiest countries')
# Out:
# Text(0.5, 1.0, 'Top 5 happiest countries')

# %%
# Top 5 sad countries
df.groupby('Country')['Happiness Score'].min().sort_values().head(5).plot(kind='bar', figsize=(8,6),color='black')
plt.title('Top 5 saddest countries')
# Out:
# Text(0.5, 1.0, 'Top 5 saddest countries')

# %%
df.groupby("Country")["Economy (GDP per Capita)"].max().sort_values(ascending=False).head(5).plot(kind='bar', figsize=(8,6),color='grey')
plt.title("Top 5 countries with high gdp")
# Out:
# Text(0.5, 1.0, 'Top 5 countries with high gdp')

# %%
# Quatar has the highest gdp

# %%
    df.groupby("Country")["Economy (GDP per Capita)"].min().sort_values().head(5).plot(kind='bar', figsize=(8,6),color='red')
    plt.title("Top 5 countries with lowest gdp")
# Out:
# Text(0.5, 1.0, 'Top 5 countries with lowest gdp')

# %%
# Congo has the lowest gdp

# %%
df.groupby("Country")["Health (Life Expectancy)"].max().sort_values(ascending=False).head(5).plot(kind='bar', figsize=(8,6),color='brown')
plt.title("Top 5 countries with high Health (Life Expectancy)")
# Out:
# Text(0.5, 1.0, 'Top 5 countries with high Health (Life Expectancy)')

# %%
# Health (Life Expectancy) highest in singapore

# %%
df.groupby("Country")["Health (Life Expectancy)"].min().sort_values().head(5).plot(kind='bar', figsize=(8,6),color='purple')
plt.title("Top 5 countries with low Health (Life Expectancy)")
# Out:
# Text(0.5, 1.0, 'Top 5 countries with low Health (Life Expectancy)')

# %%
# Sierra Leone in Africa has the lowest Health (Life Expectancy)

# %%
df.groupby("Country")["Trust (Government Corruption)"].max().sort_values(ascending=False).head(5).plot(kind='bar', figsize=(8,6),color='teal')
plt.title("Top 5 countries with high Trust (Government Corruption)")
# Out:
# Text(0.5, 1.0, 'Top 5 countries with high Trust (Government Corruption)')

# %%
# Rawanda with the highest Trust (Government Corruption)

# %%
df.groupby("Country")["Trust (Government Corruption)"].min().sort_values().head(5).plot(kind='bar', figsize=(8,6),color='limegreen')
plt.title("Top 5 countries with low Trust (Government Corruption)")
# Out:
# Text(0.5, 1.0, 'Top 5 countries with low Trust (Government Corruption)')

# %%
df.groupby("Country")["Generosity"].max().sort_values(ascending=False).head(5).plot(kind='bar', figsize=(8,6),color='red')
plt.title("Top 5 countries with high Generosity")
# Out:
# Text(0.5, 1.0, 'Top 5 countries with high Generosity')

# %%
df.groupby("Country")["Generosity"].min().sort_values().head(5).plot(kind='bar', figsize=(8,6),color='lightblue')
plt.title("Top 5 countries with low Generosity")
# Out:
# Text(0.5, 1.0, 'Top 5 countries with low Generosity')

# %%
# Lets check correlation
cor = df.corr()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data=cor,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x="Happiness Rank",y="Economy (GDP per Capita)",data=df)
plt.title("Positive relatioship")
# Out:
# Text(0.5, 1.0, 'Positive relatioship')

# %%
sns.scatterplot(x="Family",y="Happiness Score",data=df)
plt.title("Positive relatioship")
# Out:
# Text(0.5, 1.0, 'Positive relatioship')

# %%
sns.scatterplot(x="Health (Life Expectancy)",y="Happiness Score",data=df)
plt.title("Positive relatioship")
# Out:
# Text(0.5, 1.0, 'Positive relatioship')

# %%
sns.scatterplot(x="Freedom",y="Happiness Score",data=df)
plt.title("Positive relatioship")
# Out:
# Text(0.5, 1.0, 'Positive relatioship')

# %%
sns.scatterplot(x="Economy (GDP per Capita)",y="Health (Life Expectancy)",data=df)
plt.title("Positive relatioship")
# Out:
# Text(0.5, 1.0, 'Positive relatioship')

# %%
sns.scatterplot(x="Economy (GDP per Capita)",y="Family",data=df)
plt.title("Positive relatioship")
# Out:
# Text(0.5, 1.0, 'Positive relatioship')

# %%
pos = cor[cor > 0.75] #Displaying strong positive correlations
pos
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                            1.0              NaN
# Happiness Score                           NaN         1.000000
# Standard Error                            NaN              NaN
# Economy (GDP per Capita)                  NaN         0.780966
# Family                                    NaN              NaN
# Health (Life Expectancy)                  NaN              NaN
# Freedom                                   NaN              NaN
# Trust (Government Corruption)             NaN              NaN
# Generosity                                NaN              NaN
# Dystopia Residual                         NaN              NaN
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                            NaN                       NaN
# Happiness Score                           NaN                  0.780966
# ...

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
# Lets drop country, region and Happiness rank

df = df.drop(["Country","Region","Happiness Rank"],axis=1)

# %%
df.head()
# Out:
#    Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0            7.587         0.03411                   1.39651  1.34951
# 1            7.561         0.04884                   1.30232  1.40223
# 2            7.527         0.03328                   1.32548  1.36058
# 3            7.522         0.03880                   1.45900  1.33095
# 4            7.427         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# ...

# %%
plt.figure(figsize=(15,15))
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
pos
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                            1.0              NaN
# Happiness Score                           NaN         1.000000
# Standard Error                            NaN              NaN
# Economy (GDP per Capita)                  NaN         0.780966
# Family                                    NaN              NaN
# Health (Life Expectancy)                  NaN              NaN
# Freedom                                   NaN              NaN
# Trust (Government Corruption)             NaN              NaN
# Generosity                                NaN              NaN
# Dystopia Residual                         NaN              NaN
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                            NaN                       NaN
# Happiness Score                           NaN                  0.780966
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data=pos,annot=True)
# Out:
# <AxesSubplot:>

# %%
#Lets calculate outliers

# %%
from scipy import stats

# %%
#function to detect outliers
def outliers(cname):
    Q1 = df[cname].quantile(0.25)
    Q3 = df[cname].quantile(0.75)
    IQR = stats.iqr(df[cname])
    print('The first quartile :',Q1,'for',cname)
    print('The third quartile :',Q3,'for',cname)
    print('The IQR :', IQR,'for',cname)
    
    L_outlier = Q1 - 1.5*(Q3 - Q1)  
    U_outlier = Q3 + 1.5*(Q3 - Q1)

    print('The left outlier :',L_outlier,'for',cname)
    print('The Right outlier :',U_outlier,'for',cname)
    
    print("Left Outliers :",df[df[cname] < L_outlier][cname].count())
    print("Right Outliers :",df[df[cname] > U_outlier][cname].count())

# %%
df.columns
# Out:
# Index(['Happiness Score', 'Standard Error', 'Economy (GDP per Capita)',
#        'Family', 'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
# Outliers in Standard Error
outliers("Standard Error")
# Out:
# The first quartile : 0.0372675 for Standard Error
# The third quartile : 0.0523 for Standard Error
# The IQR : 0.015032499999999997 for Standard Error
# The left outlier : 0.014718750000000006 for Standard Error
# The Right outlier : 0.07484874999999999 for Standard Error
# Left Outliers : 0
# Right Outliers : 10

# %%
# Some outliers in family 
outliers("Family")
# Out:
# The first quartile : 0.8568225 for Family
# The third quartile : 1.214405 for Family
# The IQR : 0.3575824999999999 for Family
# The left outlier : 0.32044875000000017 for Family
# The Right outlier : 1.7507787499999998 for Family
# Left Outliers : 3
# Right Outliers : 0

# %%
# some outliers in Trust (Government Corruption)
outliers("Trust (Government Corruption)")
# Out:
# The first quartile : 0.061675 for Trust (Government Corruption)
# The third quartile : 0.18025500000000003 for Trust (Government Corruption)
# The IQR : 0.11858000000000002 for Trust (Government Corruption)
# The left outlier : -0.11619500000000002 for Trust (Government Corruption)
# The Right outlier : 0.358125 for Trust (Government Corruption)
# Left Outliers : 0
# Right Outliers : 14

# %%
# some outliers in Dystopia Residual
outliers("Dystopia Residual")
# Out:
# The first quartile : 1.75941 for Dystopia Residual
# The third quartile : 2.4624149999999996 for Dystopia Residual
# The IQR : 0.7030049999999997 for Dystopia Residual
# The left outlier : 0.7049025000000004 for Dystopia Residual
# The Right outlier : 3.516922499999999 for Dystopia Residual
# Left Outliers : 4
# Right Outliers : 1

# %%
# Outliers removal lets replace the values by median
def removal(cols):
    Q1 = df[cols].quantile(0.25)
    Q3 = df[cols].quantile(0.75)
    iqr = Q3 - Q1
    
    low = Q1 - 1.5*iqr
    high = Q3 + 1.5*iqr 
    
    df.loc[(df[cols] < low) | (df[cols] > high),cols] = df[cols].median()

# %%
removal("Standard Error")

# %%
# outliers removed in ("Standard Error")
outliers("Standard Error")
# Out:
# The first quartile : 0.0372675 for Standard Error
# The third quartile : 0.050145 for Standard Error
# The IQR : 0.0128775 for Standard Error
# The left outlier : 0.017951250000000002 for Standard Error
# The Right outlier : 0.06946125 for Standard Error
# Left Outliers : 0
# Right Outliers : 5

# %%
removal("Trust (Government Corruption)")

# %%
# Removing outliers in ("Trust (Government Corruption)")
outliers("Trust (Government Corruption)")
# Out:
# The first quartile : 0.061675 for Trust (Government Corruption)
# The third quartile : 0.14951 for Trust (Government Corruption)
# The IQR : 0.087835 for Trust (Government Corruption)
# The left outlier : -0.07007749999999999 for Trust (Government Corruption)
# The Right outlier : 0.28126249999999997 for Trust (Government Corruption)
# Left Outliers : 0
# Right Outliers : 10

# %%
removal("Dystopia Residual")

# %%
# Removing outliers in Dystopia Residual
outliers("Dystopia Residual")
# Out:
# The first quartile : 1.8090125 for Dystopia Residual
# The third quartile : 2.4532374999999997 for Dystopia Residual
# The IQR : 0.6442249999999998 for Dystopia Residual
# The left outlier : 0.8426750000000002 for Dystopia Residual
# The Right outlier : 3.4195749999999996 for Dystopia Residual
# Left Outliers : 0
# Right Outliers : 0

# %%
# Checking box plot
plt.figure(figsize=(15,15))
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
# using pairplot
sns.pairplot(df)

# %%
# Checking displot
sns.displot(x="Family",data=df,kind="kde")

# %%
sns.displot(x="Health (Life Expectancy)",data=df,kind="kde")

# %%
sns.displot(x="Freedom",data=df,kind="kde")

# %%
# Checking Skewness

# %%
df.columns
# Out:
# Index(['Happiness Score', 'Standard Error', 'Economy (GDP per Capita)',
#        'Family', 'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
def skw(n):
    
    return df[n].skew()

# %%
skw("Happiness Score")
# Out:
# 0.09776909409344471

# %%
skw("Standard Error")
# Out:
# 0.5820269945705627

# %%
skw("Economy (GDP per Capita)")
# Out:
# -0.31757465233120463

# %%
skw("Family")
# Out:
# -1.0068931265421135

# %%
skw("Health (Life Expectancy)")
# Out:
# -0.7053284856924459

# %%
skw("Freedom")
# Out:
# -0.41346197289710285

# %%
skw("Trust (Government Corruption)")
# Out:
# 1.122412195873384

# %%
skw("Generosity")
# Out:
# 1.001960575563042

# %%
skw("Dystopia Residual")
# Out:
# 0.09023983485367626

# %%
# Splitting the data

# %%
df.head()
# Out:
#    Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0            7.587         0.03411                   1.39651  1.34951
# 1            7.561         0.04884                   1.30232  1.40223
# 2            7.527         0.03328                   1.32548  1.36058
# 3            7.522         0.03880                   1.45900  1.33095
# 4            7.427         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.10722
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.10722
# 3                   0.88521  0.66973                        0.10722
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# ...

# %%
X = df.iloc[:,1:9]

# %%
X.head()
# Out:
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.10722
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.10722
# 3                   0.88521  0.66973                        0.10722
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
y = df.iloc[:,0]

# %%
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %%
from scipy.stats import zscore

# %%
X_scaled = X.apply(zscore)

# %%
X_scaled_df = pd.DataFrame(data=X_scaled,columns=X.columns)

# %%
X_scaled_df.head()
# Out:
#    Standard Error  Economy (GDP per Capita)    Family  \
# 0       -0.974171                  1.369621  1.320281
# 1        0.396152                  1.135226  1.514458
# 2       -1.051386                  1.192861  1.361054
# 3       -0.537863                  1.525130  1.251922
# 4       -0.842069                  1.194876  1.221204
#
#    Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 0                  1.263408  1.577438                      -0.097081
# 1                  1.289434  1.332456                       0.345073
# 2                  0.992229  1.469659                      -0.097081
# 3                  1.035145  1.605131                      -0.097081
# 4                  1.118054  1.360416                       2.775049
#
#    Generosity  Dystopia Residual
# 0    0.471040           0.811529
# 1    1.575856           1.196108
# 2    0.824293           0.758747
# 3    0.868638           0.703069
# 4    1.748563           0.674845

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=1)

# %% [markdown]
# # Using Multiple Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model_1 = LinearRegression()

# %%
model_1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model_1.score(X_train,y_train)
# Out:
# 0.9377081208678119

# %%
model_1_predict = model_1.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
model_1_acc = r2_score(y_test,model_1_predict)

# %%
model_1_acc
# Out:
# 0.9902181789567948

# %%
from sklearn.metrics import mean_squared_error
MSE_LR = mean_squared_error(y_test,model_1_predict)

# %%
MSE_LR
# Out:
# 0.011071136702425257

# %%
# Kfold Cross validation

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
k = 10
kfold = KFold(n_splits=k,shuffle=True)
K_results = cross_val_score(model_1,X,y,cv=kfold)
kfold_accuracy_lr = np.mean(abs(K_results))

# %%
kfold_accuracy_lr
# Out:
# 0.9438823440451062

# %%
K_results
# Out:
# array([0.93005442, 0.93811512, 0.97341599, 0.88383513, 0.87261538,
#        0.98897392, 0.88700114, 0.98152977, 0.99450086, 0.9887817 ])

# %%
score = {"Algorithm":["Linear Regression"],
        "R2 Score":[model_1_acc],
        "Cross_validation":[kfold_accuracy_lr],
        "Mean Square Error":[MSE_LR]}

final_card = pd.DataFrame(score)

# %%
final_card
# Out:
#            Algorithm  R2 Score  Cross_validation  Mean Square Error
# 0  Linear Regression  0.990218          0.943882           0.011071

# %% [markdown]
# # Polynomial Regression

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=1)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 2)
X_poly = poly_reg.fit_transform(X_train)
model_2 = LinearRegression()
model_2.fit(X_poly, y_train)
# Out:
# LinearRegression()

# %%
model_2_predict = model_2.predict(poly_reg.transform(X_test))

# %%
model_2_acc = r2_score(y_test,model_2_predict)

# %%
model_2_acc
# Out:
# 0.9439861028461178

# %%
MSE_PR = mean_squared_error(y_test,model_2_predict)

# %%
MSE_PR
# Out:
# 0.06339693906555177

# %%
# Kfold cross validation

# %%
k = 10
kfold = KFold(n_splits=k,shuffle=True)
K_results = cross_val_score(model_2,X,y,cv=kfold)
kfold_accuracy_Pr = np.mean(abs(K_results))

# %%
kfold_accuracy_Pr
# Out:
# 0.9427599663548035

# %%
score = {"Algorithm":["Linear Regression","Polynomial Regression"],
        "R2 Score":[model_1_acc,model_2_acc],
        "Cross_validation":[kfold_accuracy_lr,kfold_accuracy_Pr],
        "Mean Square error":[MSE_LR,MSE_PR]}

final_card = pd.DataFrame(score)

# %%
final_card
# Out:
#                Algorithm  R2 Score  Cross_validation  Mean Square error
# 0      Linear Regression  0.990218          0.943882           0.011071
# 1  Polynomial Regression  0.943986          0.942760           0.063397

# %% [markdown]
# # Random_forest_regression

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=1)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model_3 = RandomForestRegressor(n_estimators = 10, random_state = 0)
model_3.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
model_3.score(X_train,y_train)
# Out:
# 0.9543457066999881

# %%
model_3_predict = model_3.predict(X_test)

# %%
model_3_acc = r2_score(y_test,model_3_predict)

# %%
model_3_acc
# Out:
# 0.8758365980467551

# %%
MSE_RFR = mean_squared_error(y_test,model_3_predict)

# %%
MSE_RFR
# Out:
# 0.1405290477499998

# %%
# K fold cross validation

# %%
k = 10
kfold = KFold(n_splits=k,shuffle=True)
K_results = cross_val_score(model_3,X,y,cv=kfold)
kfold_accuracy_RFR = np.mean(abs(K_results))

# %%
kfold_accuracy_RFR
# Out:
# 0.8408835752337858

# %%
K_results
# Out:
# array([0.83576213, 0.8694191 , 0.76445546, 0.76097   , 0.92628033,
#        0.84118539, 0.92916477, 0.79750215, 0.90449393, 0.7796025 ])

# %%
score = {"Algorithm":["Linear Regression","Polynomial Regression",
                     "Random forest Regression"],
        "R2 Score":[model_1_acc,model_2_acc,model_3_acc],
        "Cross_validation":[kfold_accuracy_lr,kfold_accuracy_Pr,
                           kfold_accuracy_RFR],
        "Mean Square error":[MSE_LR,MSE_PR,MSE_RFR]}

final_card = pd.DataFrame(score)

# %%
final_card
# Out:
#                   Algorithm  R2 Score  Cross_validation  Mean Square error
# 0         Linear Regression  0.990218          0.943882           0.011071
# 1     Polynomial Regression  0.943986          0.942760           0.063397
# 2  Random forest Regression  0.875837          0.840884           0.140529

# %% [markdown]
# # Support Vector Regression (SVR)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=1)

# %%
from sklearn.svm import SVR

# %%
model_4 = SVR(kernel = 'rbf')
model_4.fit(X_train, y_train)
# Out:
# SVR()

# %%
model_4.score(X_train,y_train)
# Out:
# 0.9454233174118525

# %%
model_4_predict = model_4.predict(X_test)

# %%
model_4_acc = r2_score(y_test,model_4_predict)

# %%
model_4_acc
# Out:
# 0.9613164337736597

# %%
MSE_SVM = mean_squared_error(y_test,model_4_predict)

# %%
MSE_SVM
# Out:
# 0.04378234358791735

# %%
#K fold cross validation

# %%
k = 10
kfold = KFold(n_splits=k,shuffle=True)
K_results = cross_val_score(model_4,X,y,cv=kfold)
kfold_accuracy_SVM = np.mean(abs(K_results))

# %%
kfold_accuracy_SVM
# Out:
# 0.9416684773618202

# %%
K_results
# Out:
# array([0.95805077, 0.96633859, 0.99079502, 0.79772049, 0.98258293,
#        0.98883906, 0.98492397, 0.89034459, 0.8761867 , 0.98090266])

# %%
score = {"Algorithm":["Linear Regression","Polynomial Regression",
                     "Random forest Regression","SVM"],
        "R2 Score":[model_1_acc,model_2_acc,model_3_acc,model_4_acc],
        "Cross_validation":[kfold_accuracy_lr,kfold_accuracy_Pr,
                           kfold_accuracy_RFR,kfold_accuracy_SVM],
        "Mean Square error":[MSE_LR,MSE_PR,MSE_RFR,MSE_SVM]}

final_card = pd.DataFrame(score)

# %%
final_card
# Out:
#                   Algorithm  R2 Score  Cross_validation  Mean Square error
# 0         Linear Regression  0.990218          0.943882           0.011071
# 1     Polynomial Regression  0.943986          0.942760           0.063397
# 2  Random forest Regression  0.875837          0.840884           0.140529
# 3                       SVM  0.961316          0.941668           0.043782

# %% [markdown]
# # Decision Tree Regression

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=1)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model_5 = DecisionTreeRegressor()
model_5.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
model_5.score(X_train,y_train)
# Out:
# 1.0

# %%
model_5_predict = model_5.predict(X_test)

# %%
model_5_acc = r2_score(y_test,model_5_predict)

# %%
model_5_acc
# Out:
# 0.8091779666479331

# %%
MSE_DT = mean_squared_error(y_test,model_5_predict)

# %%
MSE_DT
# Out:
# 0.215973775

# %%
# Kfold cross validation

# %%
k = 10
kfold = KFold(n_splits=k,shuffle=True)
K_results = cross_val_score(model_5,X,y,cv=kfold)
kfold_accuracy_DT = np.mean(abs(K_results))

# %%
kfold_accuracy_DT
# Out:
# 0.6587151079573429

# %%
score = {"Algorithm":["Linear Regression","Polynomial Regression",
                     "Random forest Regression","SVM","Decision Tree"],
        "R2 Score":[model_1_acc,model_2_acc,model_3_acc,model_4_acc,model_5_acc],
        "Cross_validation":[kfold_accuracy_lr,kfold_accuracy_Pr,
                           kfold_accuracy_RFR,kfold_accuracy_SVM,
                           kfold_accuracy_DT],
        "Mean Square error":[MSE_LR,MSE_PR,MSE_RFR,MSE_SVM,MSE_DT]}

final_card = pd.DataFrame(score)

# %%
final_card
# Out:
#                   Algorithm  R2 Score  Cross_validation  Mean Square error
# 0         Linear Regression  0.990218          0.943882           0.011071
# 1     Polynomial Regression  0.943986          0.942760           0.063397
# 2  Random forest Regression  0.875837          0.840884           0.140529
# 3                       SVM  0.961316          0.941668           0.043782
# 4             Decision Tree  0.809178          0.658715           0.215974

# %% [markdown]
# # Gradient Bosting Regressor

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=1)

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
model_6 = GradientBoostingRegressor()

# %%
model_6.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
model_6.score(X_train,y_train)
# Out:
# 0.9980057333149254

# %%
model_6_predict = model_6.predict(X_test)

# %%
model_6_acc = r2_score(y_test,model_6_predict)

# %%
model_6_acc
# Out:
# 0.934574009146691

# %%
MSE_GB = mean_squared_error(y_test,model_6_predict)

# %%
MSE_GB
# Out:
# 0.074049615652267

# %%
# Kfold CV

# %%
k = 10
kfold = KFold(n_splits=k,shuffle=True)
K_results = cross_val_score(model_6,X,y,cv=kfold)
kfold_accuracy_GB = np.mean(abs(K_results))

# %%
kfold_accuracy_GB
# Out:
# 0.8977189625209807

# %%
score = {"Algorithm":["Linear Regression","Polynomial Regression",
                     "Random forest Regression","SVM","Decision Tree",
                     "Gradient Boosting"],
        "R2 Score":[model_1_acc,model_2_acc,model_3_acc,model_4_acc,model_5_acc,
                   model_6_acc],
        "Cross_validation":[kfold_accuracy_lr,kfold_accuracy_Pr,
                           kfold_accuracy_RFR,kfold_accuracy_SVM,
                           kfold_accuracy_DT,kfold_accuracy_GB],
        "Mean Square error":[MSE_LR,MSE_PR,MSE_RFR,MSE_SVM,MSE_DT,MSE_GB]}

final_card = pd.DataFrame(score)

# %%
final_card
# Out:
#                   Algorithm  R2 Score  Cross_validation  Mean Square error
# 0         Linear Regression  0.990218          0.943882           0.011071
# 1     Polynomial Regression  0.943986          0.942760           0.063397
# 2  Random forest Regression  0.875837          0.840884           0.140529
# 3                       SVM  0.961316          0.941668           0.043782
# 4             Decision Tree  0.809178          0.658715           0.215974
# 5         Gradient Boosting  0.934574          0.897719           0.074050

# %% [markdown]
# # ADA Boosting regressor

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=1)

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
model_7 = AdaBoostRegressor()

# %%
model_7.fit(X_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
model_7.score(X_train,y_train)
# Out:
# 0.9399813338031332

# %%
model_7_predict = model_7.predict(X_test)

# %%
model_7_acc = r2_score(y_test,model_7_predict)

# %%
model_7_acc
# Out:
# 0.8977530937225718

# %%
MSE_ADA = mean_squared_error(y_test,model_7_predict)

# %%
MSE_ADA
# Out:
# 0.11572379741947739

# %%
# Kfold

# %%
k = 10
kfold = KFold(n_splits=k,shuffle=True)
K_results = cross_val_score(model_7,X,y,cv=kfold)
kfold_accuracy_ADA = np.mean(abs(K_results))

# %%
kfold_accuracy_ADA
# Out:
# 0.7814662661598912

# %%
score = {"Algorithm":["Linear Regression","Polynomial Regression",
                     "Random forest Regression","SVM","Decision Tree",
                     "Gradient Boosting","ADA Boost"],
        "R2 Score":[model_1_acc,model_2_acc,model_3_acc,model_4_acc,model_5_acc,
                   model_6_acc,model_7_acc],
        "Cross_validation":[kfold_accuracy_lr,kfold_accuracy_Pr,
                           kfold_accuracy_RFR,kfold_accuracy_SVM,
                           kfold_accuracy_DT,kfold_accuracy_GB,
                           kfold_accuracy_ADA],
        "Mean Square error":[MSE_LR,MSE_PR,MSE_RFR,MSE_SVM,MSE_DT,MSE_GB,
                            MSE_ADA]}

final_card = pd.DataFrame(score)

# %%
final_card
# Out:
#                   Algorithm  R2 Score  Cross_validation  Mean Square error
# 0         Linear Regression  0.990218          0.943882           0.011071
# 1     Polynomial Regression  0.943986          0.942760           0.063397
# 2  Random forest Regression  0.875837          0.840884           0.140529
# 3                       SVM  0.961316          0.941668           0.043782
# 4             Decision Tree  0.809178          0.658715           0.215974
# 5         Gradient Boosting  0.934574          0.897719           0.074050
# 6                 ADA Boost  0.897753          0.781466           0.115724

# %%
final_card["Difference"] = final_card["R2 Score"] - final_card["Cross_validation"]

# %%
final_card
# Out:
#                   Algorithm  R2 Score  Cross_validation  Mean Square error  \
# 0         Linear Regression  0.990218          0.943882           0.011071
# 1     Polynomial Regression  0.943986          0.942760           0.063397
# 2  Random forest Regression  0.875837          0.840884           0.140529
# 3                       SVM  0.961316          0.941668           0.043782
# 4             Decision Tree  0.809178          0.658715           0.215974
# 5         Gradient Boosting  0.934574          0.897719           0.074050
# 6                 ADA Boost  0.897753          0.781466           0.115724
#
#    Difference
# 0    0.046336
# 1    0.001226
# 2    0.034953
# 3    0.019648
# 4    0.150463
# 5    0.036855
# 6    0.116287

# %%
# Using Linear regression model

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
print("MAE :",mean_absolute_error(y_test,model_1_predict))
# Out:
# MAE : 0.08278730467385748

# %%
print("MSE :",mean_squared_error(y_test,model_1_predict))
# Out:
# MSE : 0.011071136702425257

# %%
print("RMSE :",np.sqrt(mean_absolute_error(y_test,model_1_predict)))
# Out:
# RMSE : 0.2877278308990242

# %%
# Using Regularization

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
lasso = Lasso(alpha=0.0001)

# %%
lasso.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.0001)

# %%
lasso.score(X_train,y_train)
# Out:
# 0.9377080947743046

# %%
lasso.coef_
# Out:
# array([-0.00672686,  0.45843169,  0.29074915,  0.18999358,  0.20048314,
#         0.0718415 ,  0.06644139,  0.4777461 ])

# %%
plt.figure(figsize=(15,15))
plt.bar(X.columns,lasso.coef_)
plt.tight_layout(pad=0.3)

# %%
Ridge = Ridge(alpha=0.001)

# %%
Ridge.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.001)

# %%
Ridge.score(X_train,y_train)
# Out:
# 0.9377081208346236

# %%
Ridge.coef_
# Out:
# array([-0.00679161,  0.45837222,  0.29075672,  0.19009055,  0.20050912,
#         0.07190091,  0.06649641,  0.47783001])

# %%
plt.figure(figsize=(15,15))
plt.bar(X.columns,Ridge.coef_,color='r')
plt.tight_layout(pad=0.3)

# %%
# Training score for linear regression
model_1.score(X_train,y_train)
# Out:
# 0.9377081208678119

# %%
# Testing score for linear regression
model_1.score(X_test,y_test)
# Out:
# 0.9902181789567948

# %%
# After Reguralization

# %%
lasso.score(X_train,y_train)
# Out:
# 0.9377080947743046

# %%
lasso.score(X_test,y_test)
# Out:
# 0.9902121863485323

# %%
Ridge.score(X_train,y_train)
# Out:
# 0.9377081208346236

# %%
Ridge.score(X_test,y_test)
# Out:
# 0.9902186374340753

# %%
df.head()
# Out:
#    Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0            7.587         0.03411                   1.39651  1.34951
# 1            7.561         0.04884                   1.30232  1.40223
# 2            7.527         0.03328                   1.32548  1.36058
# 3            7.522         0.03880                   1.45900  1.33095
# 4            7.427         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.10722
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.10722
# 3                   0.88521  0.66973                        0.10722
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# ...

# %%
print("Predicted Values :",model_1_predict)
print("\n")
print("Actual Values :",y_test.values)
# Out:
# Predicted Values : [6.64098108 4.6581734  7.11503613 5.23321629 4.33002933 6.72863632
#  5.29566177 7.25455648 6.24090986 4.77241108 4.96265028 4.96170893
#  4.60116549 4.92332792 5.86536363 5.10011797 6.12719823 5.98219108
#  5.83644803 3.67159716 5.88373311 6.37018064 3.82897349 7.19818518
#  4.29668584 6.53202543 6.7687272  5.18233779 4.27539126 5.05121824
#  4.39763513 2.74979029 4.10611701 6.01785929 4.57051859 5.12134487
#  5.29263078 4.83181283 6.35178044 3.40374157]
#
#
# Actual Values : [6.574 4.715 7.119 5.192 4.419 6.901 5.399 7.226 6.168 4.949 4.867 5.007
#  4.694 4.959 5.813 5.098 6.123 5.855 5.889 3.781 5.791 6.329 3.845 7.406
#  4.35  6.485 6.946 5.253 4.518 5.013 4.514 2.905 4.077 5.995 4.332 5.124
#  5.268 4.8   6.455 3.575]

# %%
import joblib

# %%
joblib.dump(model_1,"HappyWorldNew")
# Out:
# ['HappyWorldNew']

# %%
happy = joblib.load("HappyWorldNew")

# %%
happy.predict([[0.03, 1.4 , 1.35, 0.94, 0.67, 0.42, 0.3 , 2.52]])
# Out:
# array([7.96952022])

# %%
final_card
# Out:
#                   Algorithm  R2 Score  Cross_validation  Mean Square error  \
# 0         Linear Regression  0.990218          0.943882           0.011071
# 1     Polynomial Regression  0.943986          0.942760           0.063397
# 2  Random forest Regression  0.875837          0.840884           0.140529
# 3                       SVM  0.961316          0.941668           0.043782
# 4             Decision Tree  0.809178          0.658715           0.215974
# 5         Gradient Boosting  0.934574          0.897719           0.074050
# 6                 ADA Boost  0.897753          0.781466           0.115724
#
#    Difference
# 0    0.046336
# 1    0.001226
# 2    0.034953
# 3    0.019648
# 4    0.150463
# 5    0.036855
# 6    0.116287
